# %%
import yfinance as yf #yahoo finance api
nf500t = yf.Ticker("^CRSLDX") #ticker symbol of nifty 500
nf500h = nf500t.history(period="max")

# %%
nf500h
# Out:
#                                    Open          High           Low  \
# Date
# 2005-09-26 00:00:00+05:30   2195.747135   2247.497068   2195.747135
# 2005-09-27 00:00:00+05:30   2246.247087   2274.797099   2241.297143
# 2005-09-28 00:00:00+05:30   2261.297144   2282.396970   2250.647011
# 2005-09-29 00:00:00+05:30   2289.547109   2302.297093   2275.547127
# 2005-09-30 00:00:00+05:30   2284.097155   2284.896959   2242.847208
# ...                                 ...           ...           ...
# 2025-07-14 00:00:00+05:30  23290.150391  23329.199219  23200.099609
# 2025-07-15 00:00:00+05:30  23334.550781  23469.449219  23332.800781
# 2025-07-16 00:00:00+05:30  23458.900391  23502.900391  23403.500000
# 2025-07-17 00:00:00+05:30  23507.650391  23514.699219  23409.050781
# 2025-07-18 00:00:00+05:30  23430.000000  23449.449219  23240.849609
#
#                                   Close    Volume  Dividends  Stock Splits
# Date
# ...

# %%
nf500h.index
# Out:
# DatetimeIndex(['2005-09-26 00:00:00+05:30', '2005-09-27 00:00:00+05:30',
#                '2005-09-28 00:00:00+05:30', '2005-09-29 00:00:00+05:30',
#                '2005-09-30 00:00:00+05:30', '2005-10-03 00:00:00+05:30',
#                '2005-10-04 00:00:00+05:30', '2005-10-05 00:00:00+05:30',
#                '2005-10-06 00:00:00+05:30', '2005-10-07 00:00:00+05:30',
#                ...
#                '2025-07-07 00:00:00+05:30', '2025-07-08 00:00:00+05:30',
#                '2025-07-09 00:00:00+05:30', '2025-07-10 00:00:00+05:30',
#                '2025-07-11 00:00:00+05:30', '2025-07-14 00:00:00+05:30',
#                '2025-07-15 00:00:00+05:30', '2025-07-16 00:00:00+05:30',
#                '2025-07-17 00:00:00+05:30', '2025-07-18 00:00:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', name='Date', length=4873, freq=None)

# %%
nf500h.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del nf500h["Dividends"]
del nf500h["Stock Splits"]
# delete columns dividend and stock splits

# %%
nf500h["NextDay"] = nf500h["Close"].shift(-1) #create new column called next day and use the closing price of next day

# %%
nf500h
# Out:
#                                    Open          High           Low  \
# Date
# 2005-09-26 00:00:00+05:30   2195.747135   2247.497068   2195.747135
# 2005-09-27 00:00:00+05:30   2246.247087   2274.797099   2241.297143
# 2005-09-28 00:00:00+05:30   2261.297144   2282.396970   2250.647011
# 2005-09-29 00:00:00+05:30   2289.547109   2302.297093   2275.547127
# 2005-09-30 00:00:00+05:30   2284.097155   2284.896959   2242.847208
# ...                                 ...           ...           ...
# 2025-07-14 00:00:00+05:30  23290.150391  23329.199219  23200.099609
# 2025-07-15 00:00:00+05:30  23334.550781  23469.449219  23332.800781
# 2025-07-16 00:00:00+05:30  23458.900391  23502.900391  23403.500000
# 2025-07-17 00:00:00+05:30  23507.650391  23514.699219  23409.050781
# 2025-07-18 00:00:00+05:30  23430.000000  23449.449219  23240.849609
#
#                                   Close    Volume       NextDay
# Date
# 2005-09-26 00:00:00+05:30   2245.396973         0   2259.347168
# ...

# %%
nf500h["Target"] = (nf500h["NextDay"] > nf500h["Close"]).astype(int) #create another column for target feature, if next day closing higher than prev day closing then 1, or else 0
nf500h
# Out:
#                                    Open          High           Low  \
# Date
# 2005-09-26 00:00:00+05:30   2195.747135   2247.497068   2195.747135
# 2005-09-27 00:00:00+05:30   2246.247087   2274.797099   2241.297143
# 2005-09-28 00:00:00+05:30   2261.297144   2282.396970   2250.647011
# 2005-09-29 00:00:00+05:30   2289.547109   2302.297093   2275.547127
# 2005-09-30 00:00:00+05:30   2284.097155   2284.896959   2242.847208
# ...                                 ...           ...           ...
# 2025-07-14 00:00:00+05:30  23290.150391  23329.199219  23200.099609
# 2025-07-15 00:00:00+05:30  23334.550781  23469.449219  23332.800781
# 2025-07-16 00:00:00+05:30  23458.900391  23502.900391  23403.500000
# 2025-07-17 00:00:00+05:30  23507.650391  23514.699219  23409.050781
# 2025-07-18 00:00:00+05:30  23430.000000  23449.449219  23240.849609
#
#                                   Close    Volume       NextDay  Target
# Date
# ...

# %%
nf500h.index
# Out:
# DatetimeIndex(['2005-09-26 00:00:00+05:30', '2005-09-27 00:00:00+05:30',
#                '2005-09-28 00:00:00+05:30', '2005-09-29 00:00:00+05:30',
#                '2005-09-30 00:00:00+05:30', '2005-10-03 00:00:00+05:30',
#                '2005-10-04 00:00:00+05:30', '2005-10-05 00:00:00+05:30',
#                '2005-10-06 00:00:00+05:30', '2005-10-07 00:00:00+05:30',
#                ...
#                '2025-07-07 00:00:00+05:30', '2025-07-08 00:00:00+05:30',
#                '2025-07-09 00:00:00+05:30', '2025-07-10 00:00:00+05:30',
#                '2025-07-11 00:00:00+05:30', '2025-07-14 00:00:00+05:30',
#                '2025-07-15 00:00:00+05:30', '2025-07-16 00:00:00+05:30',
#                '2025-07-17 00:00:00+05:30', '2025-07-18 00:00:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', name='Date', length=4873, freq=None)

# %%
nf500h = nf500h.loc["2011-01-01":].copy() # copy only data after 2011
nf500h
# Out:
#                                    Open          High           Low  \
# Date
# 2011-01-03 00:00:00+05:30   4964.493656   4980.443831   4959.893564
# 2011-01-04 00:00:00+05:30   4975.593726   4988.243612   4947.093763
# 2011-01-05 00:00:00+05:30   4954.343684   4954.343684   4891.743667
# 2011-01-06 00:00:00+05:30   4918.043388   4926.793376   4850.893573
# 2011-01-07 00:00:00+05:30   4855.493512   4863.943696   4737.793474
# ...                                 ...           ...           ...
# 2025-07-14 00:00:00+05:30  23290.150391  23329.199219  23200.099609
# 2025-07-15 00:00:00+05:30  23334.550781  23469.449219  23332.800781
# 2025-07-16 00:00:00+05:30  23458.900391  23502.900391  23403.500000
# 2025-07-17 00:00:00+05:30  23507.650391  23514.699219  23409.050781
# 2025-07-18 00:00:00+05:30  23430.000000  23449.449219  23240.849609
#
#                                   Close    Volume       NextDay  Target
# Date
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)
#n_estimators is the number of random forest trees, min_samples_split helps to reduce overfitting, random_state=1 mentions the randomness of each tree to be the same randomness
#so that the next time you run it, it takes the same random parameters and you get similar testinf and training results

train = nf500h.iloc[:-100]
test = nf500h.iloc[-100:]


#now we train
predictors = ["Close","Volume","Open","High","Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score #precision score is exactly what it sounds like
import pandas as pd


#prediction
preds = model.predict(test[predictors])# returns np array, therefore convert to pandas sereis
preds =pd.Series(preds, index=test.index)# use same index as previous dataset
preds
# Out:
# Date
# 2025-02-20 00:00:00+05:30    1
# 2025-02-21 00:00:00+05:30    1
# 2025-02-24 00:00:00+05:30    1
# 2025-02-25 00:00:00+05:30    1
# 2025-02-27 00:00:00+05:30    1
#                             ..
# 2025-07-14 00:00:00+05:30    1
# 2025-07-15 00:00:00+05:30    1
# 2025-07-16 00:00:00+05:30    1
# 2025-07-17 00:00:00+05:30    1
# 2025-07-18 00:00:00+05:30    0
# Length: 100, dtype: int64

# %%
#findinf accuracy
precision_score(test["Target"], preds)
# Out:
# 0.5161290322580645

# %%
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#backtesting system
def predict(train, test, predictors, model):
  model.fit(train[predictors], train["Target"])
  preds = model.predict(test[predictors])
  preds = pd.Series(preds, index=test.index, name="Predictions")
  combined = pd.concat([test["Target"], preds], axis=1)
  return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
  all_predictions = []
  for i in range(start, data.shape[0], step):
    train = data.iloc[0:i].copy()
    test = data.iloc[i:(i+step)].copy()
    predictions = predict(train, test, predictors, model)
    all_predictions.append(predictions)
  return pd.concat(all_predictions)

# %%
predictions = backtest(nf500h, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    553
# 1    524
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5515267175572519

# %%
horizons = [2,5,60,250,1000]
new_predictors = []
for horizon in horizons:
  rolling_averages = nf500h.rolling(horizon).mean()

  ratio_column = f"Close_Ratio_{horizon}"
  nf500h[ratio_column] = nf500h["Close"] / rolling_averages["Close"]

  trend_column = f"Trend_{horizon}"
  nf500h[trend_column] = nf500h.shift(1).rolling(horizon).sum()["Target"]

  new_predictors+= [ratio_column, trend_column]

# %%
nf500h
# Out:
#                                    Open          High           Low  \
# Date
# 2011-01-03 00:00:00+05:30   4964.493656   4980.443831   4959.893564
# 2011-01-04 00:00:00+05:30   4975.593726   4988.243612   4947.093763
# 2011-01-05 00:00:00+05:30   4954.343684   4954.343684   4891.743667
# 2011-01-06 00:00:00+05:30   4918.043388   4926.793376   4850.893573
# 2011-01-07 00:00:00+05:30   4855.493512   4863.943696   4737.793474
# ...                                 ...           ...           ...
# 2025-07-14 00:00:00+05:30  23290.150391  23329.199219  23200.099609
# 2025-07-15 00:00:00+05:30  23334.550781  23469.449219  23332.800781
# 2025-07-16 00:00:00+05:30  23458.900391  23502.900391  23403.500000
# 2025-07-17 00:00:00+05:30  23507.650391  23514.699219  23409.050781
# 2025-07-18 00:00:00+05:30  23430.000000  23449.449219  23240.849609
#
#                                   Close    Volume       NextDay  Target  \
# Date
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
  model.fit(train[predictors], train["Target"])
  preds = model.predict_proba(test[predictors])[:,1] #returns probablility instead of 1 or 0
  preds[preds >= .6] = 1
  preds[preds < .6] = 0       #increasing the confidence of the model
  preds = pd.Series(preds, index=test.index, name="Predictions")
  combined = pd.concat([test["Target"], preds], axis=1)
  return combined

# %%
predictions = backtest(nf500h, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    909
# 1.0    168
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.6607142857142857

# %%
nf500tt = yf.Ticker("^CRSLDX") #ticker symbol of nifty 500
nf500ht = nf500t.history(period="2d")
del nf500ht["Dividends"]
del nf500ht["Stock Splits"]
nf500ht["Target"] = (nf500ht["Close"].shift(-1) > nf500ht["Close"]).astype(int)

# %%
nf500ht
# Out:
#                                    Open          High           Low  \
# Date
# 2025-07-17 00:00:00+05:30  23507.650391  23514.699219  23409.050781
# 2025-07-18 00:00:00+05:30  23430.000000  23449.449219  23240.849609
#
#                                   Close    Volume  Target
# Date
# 2025-07-17 00:00:00+05:30  23419.699219  21951000       0
# 2025-07-18 00:00:00+05:30  23275.150391         0       0

# %%
tprediction = predict(train, nf500ht, predictors, model)
return combined
if tprediction[Predictions] > 0:
  print("Buy")
else:
  print("Sell")

# %%
tprediction
# Out:
#                            Target  Predictions
# Date
# 2025-07-17 00:00:00+05:30       0          0.0
# 2025-07-18 00:00:00+05:30       0          0.0
